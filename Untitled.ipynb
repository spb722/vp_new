# %%
from graph import run_vp_graph

  # Simple run
result = run_vp_graph("subscribers with 5+ recharges last month")

# %%
import importlib, graph                                                                                                                                                                                                          
importlib.reload(graph)                                                                                                                                                                                                          
from graph import run_vp_graph, explain_result                                                                                                                                                                             
result = run_vp_graph("subscribers with 5+ recharges last month")                                                                                                                                                                
explain_result(result)
# Out:
# Loaded seeds: 148
# First seed: S01_fixed_month_sum
# Duplicate IDs already present: ['S134_last_n_months_sum_lower_only', 'S135_last_n_months_max_lower_only', 'S136_last_n_weeks_sum_lower_only', 'S137_simple_count_all_generic', 'S138_last_n_months_count_all_lower_only', 'S139_time_scoped_presence_count_gt_zero', 'S140_sum_with_fixed_count_constraint', 'S141_percentage_of_kpi_formula', 'S142_avg_formula_months_lower_only', 'S143_avg_formula_days_currenttime_lower_only', 'S144_avg_formula_weeks_lower_only', 'S145_campaign_promo_absent_parameterized_days', 'S146_product_presence_days', 'S147_last_n_days_sum_groupby', 'S148_simple_count_all_groupby']
# Total seeds after append: 148
# Saved: data/vp_seed_catalog_with_selection_metadata.json
#
# ...
#   ✗  VP RESOLVER  — FAILED
# ...
#
# Path taken: parse_request → select_seed → stop_failure
#
# ── Node 1: parse_request ────────────────────────────────
#   agg_type      : None
#   kpi_text      : None
#   time          : 1 MONTHS  completed=True
# ...

# %%
Use CONTEXT7 to integrate it to LangSmith TO our project  so that for each execution, API call, and node, I will know:
1. What the input is
2. What the output is
3. Why my runtime is failing (in some cases)
